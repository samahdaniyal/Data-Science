# %% [markdown]
# # Homework 1
# ## Data Cleaning and Wrangling in Python
# ### Syeda Samah Daniyal, 07838
# ### sd07838@st.habib.edu.pk

# %%
import pandas as pd

# %%
data = pd.read_csv('580SurveyCleanup2.csv')

# %%
data.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4  \
# 0        No.             Time     Status  Duration (Seconds)  Access Code
# 1          1  10/3/2023 17:49  Completed               11646          NaN
# 2          2  10/3/2023 17:49  Completed                 113          NaN
# 3          3  10/3/2023 17:49  Completed                 572          NaN
# 4          4  10/3/2023 17:50  Completed                 365          NaN
#
#       Unnamed: 5      Unnamed: 6     Unnamed: 7 Unnamed: 8  \
# 0  Email Address      IP Address        Country     Region
# 1            NaN  100.36.167.226  United States   Virginia
# 2            NaN   98.169.26.134  United States   Virginia
# 3            NaN    98.169.52.23  United States   Virginia
# 4            NaN  69.255.182.253  United States   Virginia
#
#                Unnamed: 9  ...             Q12.1         Q12.2  \
# 0  City / Town / District  ...  Some familiarity  Average user
# ...

# %% [markdown]
# ## PART 1

# %%
#separating columns of students profile information
data_1 = data.iloc[:,1:12]

# %%
data_1.head()
# Out:
#         Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4     Unnamed: 5  \
# 0             Time     Status  Duration (Seconds)  Access Code  Email Address
# 1  10/3/2023 17:49  Completed               11646          NaN            NaN
# 2  10/3/2023 17:49  Completed                 113          NaN            NaN
# 3  10/3/2023 17:49  Completed                 572          NaN            NaN
# 4  10/3/2023 17:50  Completed                 365          NaN            NaN
#
#        Unnamed: 6     Unnamed: 7 Unnamed: 8              Unnamed: 9  \
# 0      IP Address        Country     Region  City / Town / District
# 1  100.36.167.226  United States   Virginia                 Fairfax
# 2   98.169.26.134  United States   Virginia                 Fairfax
# 3    98.169.52.23  United States   Virginia          Greenway Downs
# 4  69.255.182.253  United States   Virginia             Gainesville
#
#   Unnamed: 10 Unnamed: 11
# 0    Latitude   Longitude
# 1    -77.2891     38.8209
# ...

# %%
data_1.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
#Replacing header with first row
data_1.columns = data_1.iloc[0]
data_1 = data_1[1:]

# %%
data_1.head()
# Out:
# 0             Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
# 0      IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# 0 Longitude
# 1   38.8209
# 2   38.8605
# 3   38.9645
# ...

# %%
#getting q1 columns
data_2 = data.iloc[:,[12,13]]

# %%
data_2.head()
# Out:
#     Q1  Q1.1
# 0  2.0   4.0
# 1  NaN   1.0
# 2  1.0   NaN
# 3  1.0   NaN
# 4  1.0   NaN

# %%
#replacing header with first row
data_2.columns = data_2.iloc[0].astype(str)
data_2 = data_2[1:]

# %%
data_2.head()
# Out:
# 0  2.0  4.0
# 1  NaN  1.0
# 2  1.0  NaN
# 3  1.0  NaN
# 4  1.0  NaN
# 5  1.0  NaN

# %%
#Replace every "1" value with its respective column name
data_3 = data_2.loc[:, '2.0':'4.0'].replace(1, pd.Series(data_2.columns, data_2.columns)).fillna('')

# %%
data_3
# Out:
# 0   2.0  4.0
# 1        4.0
# 2   2.0
# 3   2.0
# 4   2.0
# 5   2.0
# 6   2.0
# 7   2.0
# 8   2.0
# 9   2.0
# 10       4.0
# 11  2.0
# 12       4.0
# 13  2.0
# 14  2.0
# 15       4.0
# 16       4.0
# 17  2.0
# 18  2.0
# 19       4.0
# 20       4.0
# 21       4.0
# 22  2.0
# 23       4.0
# 24       4.0
# 25       4.0
# 26  2.0
# 27  2.0
# 28       4.0
# 29       4.0
# 30  2.0
# 31       4.0
# 32  2.0
# 33  2.0
# 34       4.0
# 35  2.0
# 36       4.0

# %%
#concatenate Q1 columns into one final column
data_4 = pd.DataFrame(data_3.iloc[:,0] + data_3.iloc[:,1])

# %%
data_4
# Out:
#       0
# 1   4.0
# 2   2.0
# 3   2.0
# 4   2.0
# 5   2.0
# 6   2.0
# 7   2.0
# 8   2.0
# 9   2.0
# 10  4.0
# 11  2.0
# 12  4.0
# 13  2.0
# 14  2.0
# 15  4.0
# 16  4.0
# 17  2.0
# 18  2.0
# 19  4.0
# 20  4.0
# 21  4.0
# 22  2.0
# 23  4.0
# 24  4.0
# 25  4.0
# 26  2.0
# 27  2.0
# 28  4.0
# 29  4.0
# 30  2.0
# 31  4.0
# 32  2.0
# 33  2.0
# 34  4.0
# 35  2.0
# 36  4.0

# %%
data_4.columns = ['Q1']

# %%
data_4.head()
# Out:
#     Q1
# 1  4.0
# 2  2.0
# 3  2.0
# 4  2.0
# 5  2.0

# %%
data_5 = pd.concat([data_1,data_4],axis=1)

# %%
data_5.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1
# 1   38.8209  4.0
# 2   38.8605  2.0
# ...

# %%
#getting q2 columns
data_6 = data.iloc[:,[14,15,16,17]]

# %%
#replacing header with first row
data_6.columns = data_6.iloc[0].astype(str)
data_6 = data_6[1:]
data_6.head()
# Out:
# 0 Male Female NonBinary Prefer not to answer
# 1  NaN      1       NaN                  NaN
# 2  NaN      1       NaN                  NaN
# 3    1    NaN       NaN                  NaN
# 4  NaN    NaN       NaN                    1
# 5    1    NaN       NaN                  NaN

# %%
# Convert the specified columns to numeric values because code of previous question was raising a datatype error. If conversion fails, set the value to NaN.
data_6[['Male', 'Female', 'NonBinary', 'Prefer not to answer']] = data_6[['Male', 'Female', 'NonBinary', 'Prefer not to answer']].apply(pd.to_numeric, errors='coerce')
for col in ['Male', 'Female', 'NonBinary', 'Prefer not to answer']:
    data_6[col] = data_6[col].replace(1, col)

# Select the columns of interest and fill NaNs with an empty string
data_7 = data_6.loc[:, ['Male', 'Female', 'NonBinary', 'Prefer not to answer']].fillna('')

data_7
# Out:
# 0   Male  Female  NonBinary  Prefer not to answer
# 1         Female
# 2         Female
# 3   Male
# 4                            Prefer not to answer
# 5   Male
# 6         Female
# 7                 NonBinary
# 8         Female
# 9   Male
# 10  Male
# 11        Female
# 12        Female
# 13  Male
# 14        Female
# 15        Female
# 16  Male
# 17  Male
# 18  Male
# 19  Male
# 20        Female
# 21  Male
# 22        Female
# 23        Female
# 24  Male
# 25        Female
# 26  Male
# 27  Male
# 28  Male
# 29        Female
# 30  Male
# 31        Female
# 32        Female
# 33  Male
# 34  Male
# 35  Male
# 36        Female

# %%
data_8 = pd.DataFrame(data_7.iloc[:, 0] + data_7.iloc[:, 1] + data_7.iloc[:, 2] + data_7.iloc[:, 3])
data_8.columns = ['Q2']
data_8
# Out:
#                       Q2
# 1                 Female
# 2                 Female
# 3                   Male
# 4   Prefer not to answer
# 5                   Male
# 6                 Female
# 7              NonBinary
# 8                 Female
# 9                   Male
# 10                  Male
# 11                Female
# 12                Female
# 13                  Male
# 14                Female
# 15                Female
# 16                  Male
# 17                  Male
# 18                  Male
# 19                  Male
# 20                Female
# 21                  Male
# 22                Female
# 23                Female
# 24                  Male
# 25                Female
# 26                  Male
# 27                  Male
# 28                  Male
# 29                Female
# 30                  Male
# 31                Female
# 32                Female
# 33                  Male
# 34                  Male
# 35                  Male
# 36                Female

# %%
data_9 = pd.concat([data_1,data_4,data_8],axis=1)
data_9.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1                    Q2
# ...

# %%
#getting q3 columns
data_10 = data.iloc[:,[18]]

# %%
#replacing header with first row
data_10.columns = data_10.iloc[0].astype(str)
data_10 = data_10[1:]
data_10.columns = ['Q3']
data_10.head()
# Out:
#    Q3
# 1  23
# 2  24
# 3  40
# 4  26
# 5  30

# %%
data_11 = pd.concat([data_1,data_4,data_8,data_10],axis=1)
data_11.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1                    Q2  Q3
# ...

# %%
#getting q4 columns
data_12 = data.iloc[:,[19]]

# %%
#replacing header with first row
data_12.columns = data_12.iloc[0].astype(str)
data_12 = data_12[1:]
data_12.columns = ['Q4']
data_12.head()
# Out:
#    Q4
# 1  63
# 2  59
# 3  70
# 4  66
# 5  70

# %%
data_13 = pd.concat([data_1,data_4,data_8,data_10,data_12],axis=1)
data_13.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q5 columns
data_14 = data.iloc[:,[20]]

# %%
#replacing header with first row
data_14.columns = data_14.iloc[0].astype(str)
data_14 = data_14[1:]
data_14.columns = ['Q5']
data_14.head()
# Out:
#             Q5
# 1       Taiwan
# 2        India
# 3        India
# 4  South Korea
# 5           US

# %%
data_15 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14],axis=1)
data_15.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q6 columns
data_16 = data.iloc[:,[21]]

# %%
#replacing header with first row
data_16.columns = data_16.iloc[0].astype(str)
data_16 = data_16[1:]
data_16.columns = ['Q6']
data_16.head()
# Out:
#                       Q6
# 1              economics
# 2               Finance
# 3  Computer Applications
# 4    Business Management
# 5                    Yes

# %%
data_17 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16],axis=1)
data_17.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q7 columns
data_18 = data.iloc[:,[22]]

# %%
#replacing header with first row
data_18.columns = data_18.iloc[0].astype(str)
data_18 = data_18[1:]
data_18.columns = ['Q7']
data_18.head()
# Out:
#            Q7
# 1  12/31/2021
# 2    5/1/2021
# 3    6/1/2022
# 4  12/31/2021
# 5    1/1/2021

# %%
data_19 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18],axis=1)
data_19.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q8 columns
data_20 = data.iloc[:,[23, 24, 25, 26]]

# %%
# Replace the header with the first row
data_20.columns = data_20.iloc[0].astype(str)
data_20 = data_20[1:]

# %%
data_20[['Microsoft/Windows', 'Apple/MacBook', 'Other']] = data_20[['Microsoft/Windows', 'Apple/MacBook', 'Other']].apply(pd.to_numeric, errors='coerce')

# Replace the integer values with the corresponding column names
for col in ['Microsoft/Windows', 'Apple/MacBook', 'Other']:
    data_20[col] = data_20[col].replace({1: col, 2: col, 0: col})

# Handling the "Other" case, replacing "Other" with the actual laptop name from the next column
data_20['Other'] = data_20.apply(lambda row: row['Other'] if row['Other'] != 'Other' else row.iloc[-1], axis=1)

# Fill NaNs with an empty string and ensure all data is string type
data_20 = data_20.fillna('')

# %%
data_21 = pd.DataFrame(data_20.apply(lambda row: ', '.join(pd.unique(row[row != ''])), axis=1))
data_21.columns = ['Q8']
data_21
# Out:
#                                   Q8
# 1                      Apple/MacBook
# 2                      Apple/MacBook
# 3                      Apple/MacBook
# 4                  Microsoft/Windows
# 5                      Apple/MacBook
# 6
# 7                  Microsoft/Windows
# 8
# 9                  Microsoft/Windows
# 10
# 11                 Microsoft/Windows
# 12                 Microsoft/Windows
# 13                     Apple/MacBook
# 14                 Microsoft/Windows
# 15                 Microsoft/Windows
# 16                 Microsoft/Windows
# 17  Microsoft/Windows, Apple/MacBook
# 18                 Microsoft/Windows
# 19                 Microsoft/Windows
# 20                     Apple/MacBook
# 21                 Microsoft/Windows
# 22                 Microsoft/Windows
# 23  Microsoft/Windows, Apple/MacBook
# 24                 Microsoft/Windows
# 25                 Microsoft/Windows
# 26                 Microsoft/Windows
# 27                     Apple/MacBook
# ...

# %%
data_23 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21],axis=1)
data_23.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q9 columns
data_24 = data.iloc[:,[27, 28, 29]]

# %%
#replacing header with first row
data_24.columns = data_24.iloc[0].astype(str)
data_24 = data_24[1:]
data_24.head()
# Out:
# 0 Yes, Full Time Working, but not Full Time Not Working while attending Mason
# 1            NaN                        NaN                                 1
# 2            NaN                          1                               NaN
# 3              1                        NaN                               NaN
# 4            NaN                        NaN                                 1
# 5              1                        NaN                               NaN

# %%
data_24[['Yes, Full Time', 'Working, but not Full Time', 'Not Working while attending Mason']] = data_24[['Yes, Full Time', 'Working, but not Full Time', 'Not Working while attending Mason']].apply(pd.to_numeric, errors='coerce')
for col in ['Yes, Full Time', 'Working, but not Full Time', 'Not Working while attending Mason']:
    data_24[col] = data_24[col].replace(1, col)

# Select the columns of interest and fill NaNs with an empty string
data_25 = data_24.loc[:, ['Yes, Full Time', 'Working, but not Full Time', 'Not Working while attending Mason']].fillna('')

data_25
# Out:
# 0   Yes, Full Time  Working, but not Full Time  \
# 1
# 2                   Working, but not Full Time
# 3   Yes, Full Time
# 4
# 5   Yes, Full Time
# 6
# 7                   Working, but not Full Time
# 8
# 9   Yes, Full Time
# 10
# 11
# 12
# 13                  Working, but not Full Time
# 14
# 15
# 16
# 17  Yes, Full Time
# 18
# 19
# 20                  Working, but not Full Time
# 21  Yes, Full Time
# 22
# 23                  Working, but not Full Time
# 24
# 25  Yes, Full Time
# 26  Yes, Full Time
# 27
# 28
# 29
# 30
# 31  Yes, Full Time
# 32
# 33  Yes, Full Time
# 34  Yes, Full Time
# 35
# 36  Yes, Full Time
#
# 0   Not Working while attending Mason
# 1   Not Working while attending Mason
# 2
# 3
# 4   Not Working while attending Mason
# 5
# 6
# 7
# 8
# 9
# 10
# 11  Not Working while attending Mason
# 12  Not Working while attending Mason
# 13
# 14  Not Working while attending Mason
# 15  Not Working while attending Mason
# 16  Not Working while attending Mason
# 17
# ...

# %%
data_26 = pd.DataFrame(data_25.iloc[:, 0] + data_25.iloc[:, 1] + data_25.iloc[:, 2])
data_26.columns = ['Q9']
data_26
# Out:
#                                    Q9
# 1   Not Working while attending Mason
# 2          Working, but not Full Time
# 3                      Yes, Full Time
# 4   Not Working while attending Mason
# 5                      Yes, Full Time
# 6
# 7          Working, but not Full Time
# 8
# 9                      Yes, Full Time
# 10
# 11  Not Working while attending Mason
# 12  Not Working while attending Mason
# 13         Working, but not Full Time
# 14  Not Working while attending Mason
# 15  Not Working while attending Mason
# 16  Not Working while attending Mason
# 17                     Yes, Full Time
# 18  Not Working while attending Mason
# 19  Not Working while attending Mason
# 20         Working, but not Full Time
# 21                     Yes, Full Time
# 22  Not Working while attending Mason
# 23         Working, but not Full Time
# 24  Not Working while attending Mason
# 25                     Yes, Full Time
# 26                     Yes, Full Time
# ...

# %%
data_27 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21,data_26],axis=1)
data_27.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q10 columns
data_28 = data.iloc[:,[30,31,32,33,34]]

# %%
#replacing header with first row
data_28.columns = data_28.iloc[0].astype(str)
data_28 = data_28[1:]
data_28.head()
# Out:
# 0 Little/none Some familiarity Average user Frequent use for projects  \
# 1         NaN                1          NaN                       NaN
# 2         NaN              NaN            1                       NaN
# 3         NaN                1          NaN                       NaN
# 4         NaN              NaN            1                       NaN
# 5         NaN                1          NaN                       NaN
#
# 0 Fluent/expert
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN

# %%
data_28[['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']] = data_28[['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']].apply(pd.to_numeric, errors='coerce')
for col in ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']:
    data_28[col] = data_28[col].replace(1, col)

# Select the columns of interest and fill NaNs with an empty string
data_29 = data_28.loc[:, ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']].fillna('')

data_29
# Out:
# 0   Little/none  Some familiarity  Average user  Frequent use for projects  \
# 1                Some familiarity
# 2                                  Average user
# 3                Some familiarity
# 4                                  Average user
# 5                Some familiarity
# 6
# 7                                  Average user
# 8
# 9                Some familiarity
# 10
# 11  Little/none
# 12                                               Frequent use for projects
# 13               Some familiarity
# 14                                 Average user
# 15                                 Average user
# 16               Some familiarity
# 17                                 Average user
# 18                                               Frequent use for projects
# 19  Little/none
# 20               Some familiarity
# 21               Some familiarity
# 22               Some familiarity
# 23               Some familiarity
# 24  Little/none
# ...

# %%
data_30 = pd.DataFrame(data_29.iloc[:, 0] + data_29.iloc[:, 1] + data_29.iloc[:, 2] + data_29.iloc[:, 3] + data_29.iloc[:, 4])
data_30.columns = ['Q10']
data_30
# Out:
#                           Q10
# 1            Some familiarity
# 2                Average user
# 3            Some familiarity
# 4                Average user
# 5            Some familiarity
# 6
# 7                Average user
# 8
# 9            Some familiarity
# 10
# 11                Little/none
# 12  Frequent use for projects
# 13           Some familiarity
# 14               Average user
# 15               Average user
# 16           Some familiarity
# 17               Average user
# 18  Frequent use for projects
# 19                Little/none
# 20           Some familiarity
# 21           Some familiarity
# 22           Some familiarity
# 23           Some familiarity
# 24                Little/none
# 25               Average user
# 26               Average user
# 27               Average user
# 28               Average user
# 29               Average user
# 30               Average user
# 31                Little/none
# 32               Average user
# ...

# %%
data_31 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21,data_26,data_30],axis=1)
data_31.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q11 columns
data_32 = data.iloc[:,[35,36,37,38,39]]

# %%
#replacing header with first row
data_32.columns = data_32.iloc[0].astype(str)
data_32 = data_32[1:]
data_32.head()
# Out:
# 0 Little/none Some familiarity Average user Frequent use for projects  \
# 1           1              NaN          NaN                       NaN
# 2         NaN              NaN            1                       NaN
# 3           1              NaN          NaN                       NaN
# 4         NaN              NaN          NaN                         1
# 5         NaN                1          NaN                       NaN
#
# 0 Fluent/expert
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN

# %%
data_32[['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']] = data_32[['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']].apply(pd.to_numeric, errors='coerce')
for col in ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']:
    data_32[col] = data_32[col].replace(1, col)

# Select the columns of interest and fill NaNs with an empty string
data_33 = data_32.loc[:, ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']].fillna('')

data_33
# Out:
# 0   Little/none  Some familiarity  Average user  Frequent use for projects  \
# 1   Little/none
# 2                                  Average user
# 3   Little/none
# 4                                                Frequent use for projects
# 5                Some familiarity
# 6
# 7                                  Average user
# 8
# 9                                                Frequent use for projects
# 10
# 11  Little/none
# 12                                 Average user
# 13                                 Average user
# 14                                 Average user
# 15  Little/none
# 16               Some familiarity
# 17               Some familiarity
# 18                                               Frequent use for projects
# 19  Little/none
# 20
# 21               Some familiarity
# 22  Little/none
# 23                                               Frequent use for projects
# 24  Little/none
# 25                                 Average user
# ...

# %%
data_34 = pd.DataFrame(data_33.iloc[:, 0] + data_33.iloc[:, 1] + data_33.iloc[:, 2] + data_33.iloc[:, 3] + data_33.iloc[:, 4])
data_34.columns = ['Q11']
data_34
# Out:
#                           Q11
# 1                 Little/none
# 2                Average user
# 3                 Little/none
# 4   Frequent use for projects
# 5            Some familiarity
# 6
# 7                Average user
# 8
# 9   Frequent use for projects
# 10
# 11                Little/none
# 12               Average user
# 13               Average user
# 14               Average user
# 15                Little/none
# 16           Some familiarity
# 17           Some familiarity
# 18  Frequent use for projects
# 19                Little/none
# 20              Fluent/expert
# 21           Some familiarity
# 22                Little/none
# 23  Frequent use for projects
# 24                Little/none
# 25               Average user
# 26           Some familiarity
# 27  Frequent use for projects
# 28  Frequent use for projects
# 29               Average user
# 30               Average user
# 31           Some familiarity
# 32  Frequent use for projects
# ...

# %%
data_35 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21,data_26,data_30,data_34],axis=1)
data_35.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q12 columns
data_36 = data.iloc[:,[40,41,42,43,44]]

# %%
#replacing header with first row
data_36.columns = data_36.iloc[0].astype(str)
data_36 = data_36[1:]
data_36.head()
# Out:
# 0 Little/none Some familiarity Average user Frequent use for projects  \
# 1         NaN                1          NaN                       NaN
# 2           1              NaN          NaN                       NaN
# 3         NaN              NaN            1                       NaN
# 4         NaN                1          NaN                       NaN
# 5         NaN              NaN            1                       NaN
#
# 0 Fluent/expert
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN

# %%
data_36[['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']] = data_36[['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']].apply(pd.to_numeric, errors='coerce')
for col in ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']:
    data_36[col] = data_36[col].replace(1, col)

# Select the columns of interest and fill NaNs with an empty string
data_37 = data_36.loc[:, ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']].fillna('')

data_37
# Out:
# 0   Little/none  Some familiarity  Average user  Frequent use for projects  \
# 1                Some familiarity
# 2   Little/none
# 3                                  Average user
# 4                Some familiarity
# 5                                  Average user
# 6
# 7                                  Average user
# 8
# 9                                  Average user
# 10
# 11               Some familiarity
# 12                                               Frequent use for projects
# 13                                 Average user
# 14                                 Average user
# 15  Little/none
# 16               Some familiarity
# 17               Some familiarity
# 18                                 Average user
# 19                                 Average user
# 20                                 Average user
# 21               Some familiarity
# 22                                 Average user
# 23  Little/none
# 24  Little/none
# ...

# %%
data_38 = pd.DataFrame(data_37.iloc[:, 0] + data_37.iloc[:, 1] + data_37.iloc[:, 2] + data_37.iloc[:, 3] + data_37.iloc[:, 4])
data_38.columns = ['Q12']
data_38
# Out:
#                           Q12
# 1            Some familiarity
# 2                 Little/none
# 3                Average user
# 4            Some familiarity
# 5                Average user
# 6
# 7                Average user
# 8
# 9                Average user
# 10
# 11           Some familiarity
# 12  Frequent use for projects
# 13               Average user
# 14               Average user
# 15                Little/none
# 16           Some familiarity
# 17           Some familiarity
# 18               Average user
# 19               Average user
# 20               Average user
# 21           Some familiarity
# 22               Average user
# 23                Little/none
# 24                Little/none
# 25               Average user
# 26           Some familiarity
# 27               Average user
# 28               Average user
# 29               Average user
# 30  Frequent use for projects
# 31           Some familiarity
# 32  Frequent use for projects
# ...

# %%
data_39 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21,data_26,data_30,data_34,data_38],axis=1)
data_39.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q13 columns
data_40 = data.iloc[:,[45,46]]

# %%
#replacing header with first row
data_40.columns = data_40.iloc[0].astype(str)
data_40 = data_40[1:]
data_40.head()
# Out:
# 0  Yes   No
# 1    1  NaN
# 2    1  NaN
# 3  NaN    1
# 4  NaN    1
# 5  NaN    1

# %%
data_40[['Yes', 'No']] = data_40[['Yes', 'No']].apply(pd.to_numeric, errors='coerce')
for col in ['Yes', 'No']:
    data_40[col] = data_40[col].replace(1, col)

# Select the columns of interest and fill NaNs with an empty string
data_41 = data_40.loc[:, ['Yes', 'No']].fillna('')

# data_41 = data_40.loc[:, 'Yes':'No'].replace(1, pd.Series(data_40.columns, data_40.columns)).fillna('') #datatype error
data_41
# Out:
# 0   Yes  No
# 1   Yes
# 2   Yes
# 3        No
# 4        No
# 5        No
# 6   Yes
# 7        No
# 8   Yes
# 9   Yes
# 10       No
# 11       No
# 12       No
# 13       No
# 14       No
# 15       No
# 16       No
# 17       No
# 18       No
# 19       No
# 20       No
# 21       No
# 22       No
# 23  Yes
# 24  Yes
# 25  Yes
# 26       No
# 27       No
# 28  Yes
# 29  Yes
# 30  Yes
# 31  Yes
# 32       No
# 33       No
# 34       No
# 35       No
# 36       No

# %%
data_42 = pd.DataFrame(data_41.iloc[:, 0] + data_41.iloc[:, 1])
data_42.columns = ['Q13']
data_42
# Out:
#     Q13
# 1   Yes
# 2   Yes
# 3    No
# 4    No
# 5    No
# 6   Yes
# 7    No
# 8   Yes
# 9   Yes
# 10   No
# 11   No
# 12   No
# 13   No
# 14   No
# 15   No
# 16   No
# 17   No
# 18   No
# 19   No
# 20   No
# 21   No
# 22   No
# 23  Yes
# 24  Yes
# 25  Yes
# 26   No
# 27   No
# 28  Yes
# 29  Yes
# 30  Yes
# 31  Yes
# 32   No
# 33   No
# 34   No
# 35   No
# 36   No

# %%
data_43 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21,data_26,data_30,data_34,data_38,data_42],axis=1)
data_43.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q14 columns
data_44 = data.iloc[:,[47,48,49]]

# %%
#replacing header with first row
data_44.columns = data_44.iloc[0].astype(str)
data_44 = data_44[1:]
data_44.head()
# Out:
# 0  Yes   No Not sure
# 1    1  NaN      NaN
# 2  NaN    1      NaN
# 3  NaN  NaN        1
# 4    1  NaN      NaN
# 5    1  NaN      NaN

# %%
data_44[['Yes', 'No', 'Not sure']] = data_44[['Yes', 'No', 'Not sure']].apply(pd.to_numeric, errors='coerce')
for col in ['Yes', 'No', 'Not sure']:
    data_44[col] = data_44[col].replace(1, col)

# Select the columns of interest and fill NaNs with an empty string
data_45 = data_44.loc[:, ['Yes', 'No', 'Not sure']].fillna('')

# data_45 = data_44.loc[:, 'Yes':'Not sure'].replace(1, pd.Series(data_44.columns, data_44.columns)).fillna('') #datatype error
data_45
# Out:
# 0   Yes  No  Not sure
# 1   Yes
# 2        No
# 3            Not sure
# 4   Yes
# 5   Yes
# 6        No
# 7        No
# 8        No
# 9        No
# 10       No
# 11       No
# 12  Yes
# 13  Yes
# 14  Yes
# 15  Yes
# 16  Yes
# 17  Yes
# 18  Yes
# 19  Yes
# 20           Not sure
# 21           Not sure
# 22           Not sure
# 23           Not sure
# 24           Not sure
# 25           Not sure
# 26           Not sure
# 27  Yes
# 28  Yes
# 29  Yes
# 30  Yes
# 31  Yes
# 32  Yes
# 33       No
# 34       No
# 35           Not sure
# 36           Not sure

# %%
data_46 = pd.DataFrame(data_45.iloc[:, 0] + data_45.iloc[:, 1] + data_45.iloc[:, 2])
data_46.columns = ['Q14']
data_46
# Out:
#          Q14
# 1        Yes
# 2         No
# 3   Not sure
# 4        Yes
# 5        Yes
# 6         No
# 7         No
# 8         No
# 9         No
# 10        No
# 11        No
# 12       Yes
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18       Yes
# 19       Yes
# 20  Not sure
# 21  Not sure
# 22  Not sure
# 23  Not sure
# 24  Not sure
# 25  Not sure
# 26  Not sure
# 27       Yes
# 28       Yes
# 29       Yes
# 30       Yes
# 31       Yes
# 32       Yes
# 33        No
# 34        No
# 35  Not sure
# 36  Not sure

# %%
data_47 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21,data_26,data_30,data_34,data_38,data_42,data_46],axis=1)
data_47.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
#getting q15 columns
data_48 = data.iloc[:,[50]]

# %%
#replacing header with first row
data_48.columns = data_48.iloc[0].astype(str)
data_48 = data_48[1:]
data_48.head()
# Out:
# 0 What is your goal for learning about data analytics?
# 1                                                NaN
# 2                                                NaN
# 3  As part of my work, I have access to a lot of ...
# 4                                                NaN
# 5                                              Learn

# %%
#replacing header with first row
data_48.columns = data_48.iloc[0].astype(str)
data_48 = data_48[1:]
data_48.columns = ['Q15']
data_48.head()
# Out:
#                                                  Q15
# 2                                                NaN
# 3  As part of my work, I have access to a lot of ...
# 4                                                NaN
# 5                                              Learn
# 6                                                NaN

# %%
data_49 = pd.concat([data_1,data_4,data_8,data_10,data_12,data_14,data_16,data_18,data_21,data_26,data_30,data_34,data_38,data_42,data_46,data_48],axis=1)
data_49.head(6)
# Out:
#               Time      Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49   Completed              11646         NaN           NaN
# 2  10/3/2023 17:49   Completed                113         NaN           NaN
# 3  10/3/2023 17:49   Completed                572         NaN           NaN
# 4  10/3/2023 17:50   Completed                365         NaN           NaN
# 5  10/3/2023 17:51   Completed                 92         NaN           NaN
# 6  10/3/2023 17:59  Incomplete                221         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# ...

# %%
# data_49.to_csv('formatted_580SurveyCleanup2.csv', index=False)

# %% [markdown]
# ## PART 2

# %%
df = pd.read_csv('formatted_580SurveyCleanup2.csv')
df.head()
# Out:
#               Time     Status  Duration (Seconds)  Access Code  Email Address  \
# 0  10/3/2023 17:49  Completed               11646          NaN            NaN
# 1  10/3/2023 17:49  Completed                 113          NaN            NaN
# 2  10/3/2023 17:49  Completed                 572          NaN            NaN
# 3  10/3/2023 17:50  Completed                 365          NaN            NaN
# 4  10/3/2023 17:51  Completed                  92          NaN            NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 0  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 1   98.169.26.134  United States  Virginia                Fairfax  -77.2630
# 2    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 3  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 4  138.88.108.230  United States       NaN                    NaN  -97.8220
#
# ...

# %%
# Checking for missing values in each column
missing_values = df.isnull().sum()

# Listing columns with missing values
missing_columns = missing_values[missing_values > 0]
print("Columns with missing values and number of values missing:\n", missing_columns)
# Out:
# Columns with missing values and number of values missing:
#  Access Code               36
# Email Address             36
# Region                     4
# City / Town / District     5
# Q4                         1
# Q5                         2
# Q6                         2
# Q7                         3
# Q8                         3
# Q9                         3
# Q10                        3
# Q11                        3
# Q12                        3
# Q15                        9
# dtype: int64

# %%
#dropping access code and email address columns because they have no values hence these columns do not affect the data in any manner.
df.drop(columns=['Access Code', 'Email Address'], inplace=True)

# %%
#using reverse geocoding to fill in the missing values of region and city/town/district, reference: https://geopy.readthedocs.io/en/latest/
from geopy.geocoders import Nominatim

# Function to reverse geocode
def reverse_geocode(lat, lon):
    geolocator = Nominatim(user_agent="DS_HW")
    try:
        # Skip if latitude or longitude is NaN
        if pd.isna(lat) or pd.isna(lon):
            return '', ''
        
        # Check if latitude and longitude seem swapped, Check if latitude and longitude values are out of range Latitude should be between -90 and 90, and longitude between -180 and 180
        if abs(lat) > 90 or abs(lon) > 180:
            lat, lon = lon, lat  # Swap them
        # Use the geolocator to reverse geocode the coordinates
        # 'language' specifies the language for the returned address, 'addressdetails=True' requests detailed address information
        location = geolocator.reverse((lat, lon), language='en', addressdetails=True)
        if location:
            address = location.raw.get('address', {})
            city = address.get('city', '') or address.get('town', '') or address.get('village', '') # Get the city, town, or village, preferring 'city' over 'town' or 'village'
            region = address.get('state', '') or address.get('region', '') # Get the state or region, preferring 'state' over 'region'
            return city, region
        return '', ''
    except Exception as e:
        print(f"Error: {e} for coordinates lat={lat}, lon={lon}")
        return '', ''  # Always return two empty strings in case of error

# Update only NaN values using reverse geocoding
def update_missing_info(row):
    if pd.isna(row['Region']) or pd.isna(row['City / Town / District']):
        city, region = reverse_geocode(row['Latitude'], row['Longitude'])
        return pd.Series([city, region], index=['City / Town / District', 'Region'])
    else:
        return pd.Series([row['City / Town / District'], row['Region']], index=['City / Town / District', 'Region'])

df[['City / Town / District', 'Region']] = df.apply(update_missing_info, axis=1)

# %%
#if even after geocoding Region or city is Null (geocoding code above would make it '' instead of Nan) filling it with "Not Available" as that data hasn't been found or given
def fill_missing(value):
    return 'Not Available' if pd.isna(value) or value == '' else value

df['Region'] = df['Region'].apply(fill_missing)
df['City / Town / District'] = df['City / Town / District'].apply(fill_missing)

df
# Out:
#                Time      Status  Duration (Seconds)       IP Address  \
# 0   10/3/2023 17:49   Completed               11646   100.36.167.226
# 1   10/3/2023 17:49   Completed                 113    98.169.26.134
# 2   10/3/2023 17:49   Completed                 572     98.169.52.23
# 3   10/3/2023 17:50   Completed                 365   69.255.182.253
# 4   10/3/2023 17:51   Completed                  92   138.88.108.230
# 5   10/3/2023 17:59  Incomplete                 221    108.56.134.80
# 6   10/3/2023 18:23   Completed              115983   108.48.175.220
# 7   10/3/2023 19:10  Incomplete                  40    173.67.199.85
# 8   10/3/2023 19:25   Completed                 137     74.96.114.12
# 9   10/3/2023 19:56  Incomplete                 179    107.77.241.32
# 10  10/3/2023 20:14   Completed                 127   138.88.182.245
# 11  10/3/2023 21:38   Completed                 269     72.83.246.60
# 12  10/3/2023 21:41   Completed                 117    96.241.43.105
# ...

# %%
#replacing all NaN values in quesion with "Not Answered" as the person who filled the survey may have intentionally left that question so we cannot deduce what the answer could have been
# Example: Custom fill based on your knowledge
df.loc[df['Q4'].isnull(), 'Q4'] = 'Not Answered'
df.loc[df['Q5'].isnull(), 'Q5'] = 'Not Answered'
df.loc[df['Q6'].isnull(), 'Q6'] = 'Not Answered'
df.loc[df['Q7'].isnull(), 'Q7'] = 'Not Answered'
df.loc[df['Q8'].isnull(), 'Q8'] = 'Not Answered'
df.loc[df['Q9'].isnull(), 'Q9'] = 'Not Answered'
df.loc[df['Q10'].isnull(), 'Q10'] = 'Not Answered'
df.loc[df['Q11'].isnull(), 'Q11'] = 'Not Answered'
df.loc[df['Q12'].isnull(), 'Q12'] = 'Not Answered'
df.loc[df['Q15'].isnull(), 'Q15'] = 'Not Answered'
df
# Out:
#                Time      Status  Duration (Seconds)       IP Address  \
# 0   10/3/2023 17:49   Completed               11646   100.36.167.226
# 1   10/3/2023 17:49   Completed                 113    98.169.26.134
# 2   10/3/2023 17:49   Completed                 572     98.169.52.23
# 3   10/3/2023 17:50   Completed                 365   69.255.182.253
# 4   10/3/2023 17:51   Completed                  92   138.88.108.230
# 5   10/3/2023 17:59  Incomplete                 221    108.56.134.80
# 6   10/3/2023 18:23   Completed              115983   108.48.175.220
# 7   10/3/2023 19:10  Incomplete                  40    173.67.199.85
# 8   10/3/2023 19:25   Completed                 137     74.96.114.12
# 9   10/3/2023 19:56  Incomplete                 179    107.77.241.32
# 10  10/3/2023 20:14   Completed                 127   138.88.182.245
# 11  10/3/2023 21:38   Completed                 269     72.83.246.60
# 12  10/3/2023 21:41   Completed                 117    96.241.43.105
# ...

# %%
import numpy as np
from datetime import datetime
for column in df.columns:
    # Strip leading and trailing whitespaces
    df[column] = df[column].astype(str).str.strip()
    
    # Replace multiple spaces with a single space
    df[column] = df[column].str.replace(r'\s+', ' ', regex=True)

# Changing '2 3' to 23 in Q3 column
df['Q3'] = df['Q3'].replace('2 3', 23)

# Getting the current year
current_year = datetime.now().year

# Convert '1993' to age assuming that the survey was filled out recently
def convert_year_to_age(value):
    if str(value).isdigit() and int(value) > 1900:
        return current_year - int(value)
    return value

df['Q3'] = df['Q3'].apply(convert_year_to_age)

# Convert Q3 to numeric after replacement
df['Q3'] = pd.to_numeric(df['Q3'], errors='coerce')

# Changing '6l' and '7O' to 61 and 70 in Q4 column
df['Q4'] = df['Q4'].replace('6l', 61)
df['Q4'] = df['Q4'].replace('7O', 70)

# Function to convert 5.2 to inches assuming it is 5 feet and 2 inches
def convert_specific_value(value):
    if value == '5.2':
        feet = 5
        inches = 2
        return feet * 12 + inches
    return value

# Apply the conversion function only to the specific value '5.2'
df['Q4'] = df['Q4'].apply(convert_specific_value)

# replacing particular values in the following columns to make data consistent
df['Q5'] = df['Q5'].replace('US', 'United States of Ameria')
df['Q5'] = df['Q5'].replace('china', 'China')
df['Q5'] = df['Q5'].replace('pakistan', 'Pakistan')
df['Q5'] = df['Q5'].replace('United States ; Pakistan', 'United States of America, Pakistan')
df['Q5'] = df['Q5'].replace('USA', 'United States of America')
df['Q5'] = df['Q5'].replace('United States', 'United States of America')
df['Q6'] = df['Q6'].replace(['economics', 'Economic', 'Economics'], 'Economics')
df['Q6'] = df['Q6'].replace(['Computer Science', 'Computer science'], 'Computer Science')
df['Q6'] = df['Q6'].replace(['Computer Science', 'Computer science'], 'Computer Science')


#removing duplicates if they are there
df = df.drop_duplicates()
df
# Out:
#                Time      Status Duration (Seconds)       IP Address  \
# 0   10/3/2023 17:49   Completed              11646   100.36.167.226
# 1   10/3/2023 17:49   Completed                113    98.169.26.134
# 2   10/3/2023 17:49   Completed                572     98.169.52.23
# 3   10/3/2023 17:50   Completed                365   69.255.182.253
# 4   10/3/2023 17:51   Completed                 92   138.88.108.230
# 5   10/3/2023 17:59  Incomplete                221    108.56.134.80
# 6   10/3/2023 18:23   Completed             115983   108.48.175.220
# 7   10/3/2023 19:10  Incomplete                 40    173.67.199.85
# 8   10/3/2023 19:25   Completed                137     74.96.114.12
# 9   10/3/2023 19:56  Incomplete                179    107.77.241.32
# 10  10/3/2023 20:14   Completed                127   138.88.182.245
# 11  10/3/2023 21:38   Completed                269     72.83.246.60
# 12  10/3/2023 21:41   Completed                117    96.241.43.105
# ...

# %%
# df.to_csv('cleaned_580SurveyCleanup2.csv', index=False)

# %% [markdown]
# ## PART 3

# %%
df2 = pd.read_csv('cleaned_580SurveyCleanup2.csv')
df2.head()
# Out:
#               Time     Status  Duration (Seconds)      IP Address  \
# 0  10/3/2023 17:49  Completed               11646  100.36.167.226
# 1  10/3/2023 17:49  Completed                 113   98.169.26.134
# 2  10/3/2023 17:49  Completed                 572    98.169.52.23
# 3  10/3/2023 17:50  Completed                 365  69.255.182.253
# 4  10/3/2023 17:51  Completed                  92  138.88.108.230
#
#          Country    Region City / Town / District  Latitude  Longitude   Q1  \
# 0  United States  Virginia                Fairfax  -77.2891    38.8209  4.0
# 1  United States  Virginia                Fairfax  -77.2630    38.8605  2.0
# 2  United States  Virginia         Greenway Downs  -77.2331    38.9645  2.0
# 3  United States  Virginia            Gainesville  -77.6308    38.8175  2.0
# 4  United States    Kansas          Not Available  -97.8220    37.7510  2.0
#
#    ...                     Q6          Q7                 Q8  \
# ...

# %%
df2.describe()
# Out:
#        Duration (Seconds)   Latitude  Longitude         Q1         Q3
# count           36.000000  36.000000  36.000000  36.000000  36.000000
# mean          7571.027778 -80.093406  38.562475   2.888889  27.166667
# std          28292.029740   7.151399   1.101628   1.007905   6.518107
# min             40.000000 -97.822000  32.778700   2.000000  22.000000
# 25%            171.500000 -77.374475  38.730625   2.000000  23.000000
# 50%            263.000000 -77.286600  38.835700   2.000000  25.000000
# 75%            537.500000 -77.226325  38.931100   4.000000  28.000000
# max         128253.000000 -76.557000  39.462400   4.000000  55.000000

# %%
df2['Q1'].describe()
# Out:
# count    36.000000
# mean      2.888889
# std       1.007905
# min       2.000000
# 25%       2.000000
# 50%       2.000000
# 75%       4.000000
# max       4.000000
# Name: Q1, dtype: float64

# %% [markdown]
# #### This tells us that most of the students that filled the survey were in Section 2 of AIT-580 course's fall 2023 iteration and there were only 2 sections for this course in fall 2023.

# %%
df2['Q2'].describe()
# Out:
# count       36
# unique       4
# top       Male
# freq        18
# Name: Q2, dtype: object

# %%
df2['Q2'].unique()
# Out:
# array(['Female', 'Male', 'Prefer not to answer', 'NonBinary'],
#       dtype=object)

# %%
countF=(df['Q2']=='Female').sum()
countPNA=(df['Q2']=='Prefer not to answer').sum()
countNB=(df['Q2']=='NonBinary').sum()

print("Female = " + str(countF) + ', Prefer Not to Answer = ' + str(countPNA) + ', Non-Binary = ' + str(countNB))
# Out:
# Female = 16, Prefer Not to Answer = 1, Non-Binary = 1

# %% [markdown]
# #### This tells us that most students who filled out the survey and took the AIT-580 course's fall 2023 iteration were male. The total number of students who filled it were 36 out of which 18 were male. There were 16 females and 1 Non-binary individual.

# %%
df2['Q3'].describe()
# Out:
# count    36.000000
# mean     27.166667
# std       6.518107
# min      22.000000
# 25%      23.000000
# 50%      25.000000
# 75%      28.000000
# max      55.000000
# Name: Q3, dtype: float64

# %% [markdown]
# #### The mean age for the students was 27, while the oldest student was 55 years old and youngest was 22 years old.

# %%
# Convert Q4 to numeric to ensure all values are numbers
df2['Q4'] = pd.to_numeric(df2['Q4'], errors='coerce')
df2['Q4'].describe()
# Out:
# count    35.000000
# mean     67.342857
# std       4.283641
# min      56.000000
# 25%      66.000000
# 50%      67.000000
# 75%      70.000000
# max      75.000000
# Name: Q4, dtype: float64

# %%
df2['Q4'].unique()
# Out:
# array([63., 59., 70., 66., nan, 62., 71., 69., 67., 72., 68., 60., 74.,
#        65., 75., 61., 64., 56., 73.])

# %% [markdown]
# #### One person did not answer this question. The mean height for students in this course was 67.34 inches. The shortest person was 56 inches and tallest was 75 inches.

# %%
df2['Q5'].describe()
# Out:
# count        36
# unique       14
# top       India
# freq         10
# Name: Q5, dtype: object

# %%
df2['Q5'].unique()
# Out:
# array(['Taiwan', 'India', 'South Korea', 'United States of Ameria',
#        'Not Answered', 'Pakistan', 'China', 'Uzbekistan',
#        'United States of America', 'Romania', 'Ethiopia', 'Nigeria',
#        'United States of America, Pakistan', 'Vietnam'], dtype=object)

# %% [markdown]
# #### Most students who filled out the survey were from India (10 out of 36). Moreover, there were students of 12 nationalities; Taiwan, India, South Korea, United States of America, Pakistan, China, Uzbekistan, Romania, Ethiopia, Nigeria, and Vietnam, and one student with dual nationality of United States of America and Pakistan.m'

# %%
df2['Q6'].describe()
# Out:
# count            36
# unique           27
# top       Economics
# freq              5
# Name: Q6, dtype: object

# %% [markdown]
# #### Most of the students that took this course had an undergraduate degree in Economics. While the students enrolled mentioned 27 disctinct undergraduate degrees

# %%
df2['Q7'].describe()
# Out:
# count             36
# unique            25
# top       12/31/2021
# freq               3
# Name: Q7, dtype: object

# %% [markdown]
# #### Most of the students are expected to graduate on 12/31/2021 from Mason MS program.

# %%
df2['Q8'].describe()
# Out:
# count                    36
# unique                    5
# top       Microsoft/Windows
# freq                     21
# Name: Q8, dtype: object

# %%
df2['Q8'].unique()
# Out:
# array(['Apple/MacBook', 'Microsoft/Windows', 'Not Answered',
#        'Microsoft/Windows, Apple/MacBook', 'Acer/Windows'], dtype=object)

# %% [markdown]
# #### Most of the students own Microsoft/Windows laptop.

# %%
df2['Q9'].describe()
# Out:
# count                                    36
# unique                                    4
# top       Not Working while attending Mason
# freq                                     17
# Name: Q9, dtype: object

# %% [markdown]
# #### Most of the students were not working while attending Mason.

# %%
df2['Q10'].describe()
# Out:
# count               36
# unique               5
# top       Average user
# freq                15
# Name: Q10, dtype: object

# %% [markdown]
# #### Most student were average python programming language users.

# %%
df2['Q11'].describe()
# Out:
# count               36
# unique               6
# top       Average user
# freq                 9
# Name: Q11, dtype: object

# %% [markdown]
# #### Most student were average R programming language users.

# %%
df2['Q12'].describe()
# Out:
# count               36
# unique               5
# top       Average user
# freq                15
# Name: Q12, dtype: object

# %% [markdown]
# #### Most student were average SQL programming language users.

# %%
df2['Q13'].describe()
# Out:
# count     36
# unique     2
# top       No
# freq      24
# Name: Q13, dtype: object

# %% [markdown]
# #### Most of the students do not use Github for repository and management.

# %%
df2['Q14'].describe()
# Out:
# count      36
# unique      3
# top       Yes
# freq       17
# Name: Q14, dtype: object

# %% [markdown]
# #### Most of the students plan on pursuing Data Science/Data Analytics field as their career path.
